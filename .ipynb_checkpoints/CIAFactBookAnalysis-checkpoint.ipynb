# %%
import pandas as pd
import numpy as np
import os
import sqlite3
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'CIAFactBookAnalysis.ipynb', 'factbook.db']

# %%
conn=sqlite3.connect('factbook.db')
csr = conn.cursor()

# %%
query="SELECT * FROM sqlite_master WHERE type='table'; "
pd.read_sql_query(query, conn)
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table  sqlite_sequence  sqlite_sequence         3
# 1  table            facts            facts        47
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY...

# %%
#View first 5 rows

query="SELECT * FROM facts LIMIT 10;"
pd.read_sql(query,conn)
# Out:
#    id code                 name     area  area_land  area_water  population  \
# 0   1   af          Afghanistan   652230     652230           0    32564342
# 1   2   al              Albania    28748      27398        1350     3029278
# 2   3   ag              Algeria  2381741    2381741           0    39542166
# 3   4   an              Andorra      468        468           0       85580
# 4   5   ao               Angola  1246700    1246700           0    19625353
# 5   6   ac  Antigua and Barbuda      442        442           0       92436
# 6   7   ar            Argentina  2780400    2736690       43710    43431886
# 7   8   am              Armenia    29743      28203        1540     3056382
# 8   9   as            Australia  7741220    7682300       58920    22751014
# 9  10   au              Austria    83871      82445        1426     8665550
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# ...

# %%
#Basic statistics

query_stats='SELECT MIN(population)min_pop,MAX(population)max_pop,MIN(population_growth)min_pop_growth,\
            MAX(population_growth)max_pop_growth FROM facts;'
pd.read_sql(query_stats,conn)
# Out:
#    min_pop     max_pop  min_pop_growth  max_pop_growth
# 0        0  7256490011             0.0            4.02

# %%
#Country recorded to have zero population

query_country_zero_pop='SELECT name FROM facts WHERE population=0;'
pd.read_sql(query_country_zero_pop,conn)
# Out:
#          name
# 0  Antarctica

# %%
#country recorder to have maximum population

query_country_max_pop='SELECT name FROM facts WHERE population=7256490011;'
pd.read_sql(query_country_max_pop,conn)
# Out:
#     name
# 0  World

# %%
#Average area

avg_area_query='SELECT AVG(area) FROM facts;'
pd.read_sql(avg_area_query,conn)
# Out:
#        AVG(area)
# 0  555093.546185

# %%
#Average population

avg_pop_query='SELECT AVG(population) FROM facts;'
pd.read_sql(avg_pop_query,conn)
# Out:
#    AVG(population)
# 0     6.209493e+07

# %%
#densly populated countries

densly_pop='SELECT name FROM facts WHERE population > (SELECT AVG(population)\
                FROM facts) and area < (SELECT AVG(area) FROM facts);'
pd.read_sql(densly_pop,conn)
# Out:
#              name
# 0      Bangladesh
# 1         Germany
# 2           Japan
# 3     Philippines
# 4        Thailand
# 5  United Kingdom
# 6         Vietnam

# %%
#countries with more water than land

more_water='SELECT name FROM facts WHERE area_water > area_land;'
pd.read_sql(more_water,conn)
# Out:
#                              name
# 0  British Indian Ocean Territory
# 1                  Virgin Islands

# %%
#Which countries will add the most people to their population next year?

more_people='SELECT name FROM facts WHERE population_growth = (SELECT MAX(population_growth) FROM facts);'
pd.read_sql(more_people,conn)
# Out:
#           name
# 0  South Sudan

# %%
#Which countries have a higher death rate than birth rate?

more_deaths_than_births='SELECT name FROM facts WHERE death_rate > birth_rate;'
pd.read_sql(more_deaths_than_births,conn)
# Out:
#                          name
# 0                     Austria
# 1                     Belarus
# 2      Bosnia and Herzegovina
# 3                    Bulgaria
# 4                     Croatia
# 5              Czech Republic
# 6                     Estonia
# 7                     Germany
# 8                      Greece
# 9                     Hungary
# 10                      Italy
# 11                      Japan
# 12                     Latvia
# 13                  Lithuania
# 14                    Moldova
# 15                     Monaco
# 16                     Poland
# 17                   Portugal
# 18                    Romania
# 19                     Russia
# 20                     Serbia
# 21                   Slovenia
# 22                    Ukraine
# 23  Saint Pierre and Miquelon

# %%
csr.close()
del csr
conn.close()
